# %% [markdown]
# ### REAL-SELFHARMERS-TEXTS

# %%
import pandas as pd
# !wget https://ipfs.io/ipfs/QmUmgNCjZdLidEEbSQ5BhBGr5wtrEF5JJgc3zRg9fs5s25 -O real-selfharmers-texts.csv
real_selfharmers_texts = pd.read_csv('real-selfharmers-texts.csv')
real_selfharmers_texts
# Out:
# --2020-07-22 20:19:36--  https://ipfs.io/ipfs/QmUmgNCjZdLidEEbSQ5BhBGr5wtrEF5JJgc3zRg9fs5s25
# Resolving ipfs.io (ipfs.io)... 209.94.90.1, 2602:fea2:2::1
# Connecting to ipfs.io (ipfs.io)|209.94.90.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16640496 (16M) [text/csv]
# Saving to: ‘real-selfharmers-texts.csv’
#
# real-selfharmers-te 100%[===================>]  15.87M  14.5MB/s    in 1.1s
#
# 2020-07-22 20:19:38 (14.5 MB/s) - ‘real-selfharmers-texts.csv’ saved [16640496/16640496]
#                                                     text  ...   text_type
# 0      Bluetooth headphones flash lights then close, ...  ...  submission
# 1      My Bluetooth headphones flash between blue and...  ...     comment
# 2      im going to kill myself between March 20-April...  ...  submission
# 3      No school counselor and I can’t go to a therap...  ...     comment
# 4      Mental health isn’t so recognised in Egypt. We...  ...     comment
# ...

# %% [markdown]
# ### USERS-TEXTS-200K

# %%
import pandas as pd
# !wget https://ipfs.io/ipfs/QmcaLvBg1g2tjqKCd4f4W8jdRzqJtse9Wy1RahVmHKPJ6t -O users-texts-200k.csv
users_texts_200k = pd.read_csv('users-texts-200k.csv')
users_texts_200k
# Out:
# --2020-07-22 20:19:40--  https://ipfs.io/ipfs/QmcaLvBg1g2tjqKCd4f4W8jdRzqJtse9Wy1RahVmHKPJ6t
# Resolving ipfs.io (ipfs.io)... 209.94.90.1, 2602:fea2:2::1
# Connecting to ipfs.io (ipfs.io)|209.94.90.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36137822 (34M) [text/csv]
# Saving to: ‘users-texts-200k.csv’
#
# users-texts-200k.cs 100%[===================>]  34.46M  18.9MB/s    in 1.8s
#
# 2020-07-22 20:19:42 (18.9 MB/s) - ‘users-texts-200k.csv’ saved [36137822/36137822]
#                                                      text  ...   text_type
# 0       Ok, changed it. Thanks for the tip! As for the...  ...     comment
# 1       Beautiful woman from my church with a shameful...  ...  submission
# 2       It is perfectly fine to rely on the pill for b...  ...     comment
# 3       So I agree to use condoms for now, but if y'al...  ...     comment
# 4                                funny looking mouse then  ...     comment
# ...

# %% [markdown]
# ### USERS-TEXTS-2M

# %%
import pandas as pd
# !wget https://ipfs.io/ipfs/QmWVU346JqpPg5L7YJxBB3NaJHjokyD1fQcqd5TzFejCpK -O users-texts-2m.csv
users_texts_2m = pd.read_csv('users-texts-2m.csv')
users_texts_2m
# Out:
# --2020-07-22 20:19:44--  https://ipfs.io/ipfs/QmWVU346JqpPg5L7YJxBB3NaJHjokyD1fQcqd5TzFejCpK
# Resolving ipfs.io (ipfs.io)... 209.94.90.1, 2602:fea2:2::1
# Connecting to ipfs.io (ipfs.io)|209.94.90.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 363758237 (347M) [text/csv]
# Saving to: ‘users-texts-2m.csv’
#
# users-texts-2m.csv  100%[===================>] 346.91M  35.4MB/s    in 12s
#
# 2020-07-22 20:19:57 (28.0 MB/s) - ‘users-texts-2m.csv’ saved [363758237/363758237]
#                                                       text  ...  text_type
# 0                                            Best episode.  ...    comment
# 1                                              r/titlegore  ...    comment
# 2        Something always looks... off with the devil f...  ...    comment
# 3        You got an upvote at "not for art but for... w...  ...    comment
# 4        I think it's like having a wizard with a high ...  ...    comment
# ...

# %% [markdown]
# ### USERS-SUBMISSIONS-200K

# %%
import pandas as pd
# !wget https://ipfs.io/ipfs/QmW1bTBUkf56E9qgwUS99qoxJxvZAFJPdHgRTri6xip46N -O users-submissions-200k.csv
users_submissions_200k = pd.read_csv('users-submissions-200k.csv')
users_submissions_200k
# Out:
# --2020-07-22 20:20:03--  https://ipfs.io/ipfs/QmW1bTBUkf56E9qgwUS99qoxJxvZAFJPdHgRTri6xip46N
# Resolving ipfs.io (ipfs.io)... 209.94.90.1, 2602:fea2:2::1
# Connecting to ipfs.io (ipfs.io)|209.94.90.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58904670 (56M) [text/csv]
# Saving to: ‘users-submissions-200k.csv’
#
# users-submissions-2 100%[===================>]  56.18M  21.9MB/s    in 2.6s
#
# 2020-07-22 20:20:06 (21.9 MB/s) - ‘users-submissions-200k.csv’ saved [58904670/58904670]
#                                                      text  ...   text_type
# 0       [CONTEST] Giving away a 20 dollar e-gift card ...  ...  submission
# 1       All I ask is that you follow the sub's rules (...  ...  submission
# 2       giving head will be so much more [f]un with my...  ...  submission
# 3                        Alright, hand over that 6 karma.  ...  submission
# 4       why am i still in pain?. im on meds and in the...  ...  submission
# ...
